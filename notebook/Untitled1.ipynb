# %%
import numpy as np

# %%
10 * np.random.randn(100)
# Out:
# array([ -2.03438375e+01,   5.87879725e+00,  -1.39883759e+01,
#         -1.41070534e+01,   8.43776949e-01,  -5.29139887e+00,
#          1.93981005e+00,  -5.26476559e+00,   3.74982011e+00,
#         -7.59541182e+00,   4.79630900e+00,   7.83589157e+00,
#         -7.40562019e+00,  -1.31561178e-02,   2.29644763e+01,
#          1.65050175e+01,  -8.79229821e+00,   1.49604503e+00,
#         -6.72297259e+00,   1.19821950e+01,  -1.14848331e+01,
#          2.99133514e+01,   1.18138806e+01,  -2.29840001e-01,
#         -1.73659341e+00,  -1.41303515e+01,  -7.73284914e+00,
#          6.19061099e+00,   2.68864480e-01,  -4.83017411e+00,
#          1.40862429e+00,  -1.53820879e+01,   1.28024291e+01,
#          1.00564888e+01,   5.54169988e+00,  -1.10302936e+01,
#         -5.05042879e+00,   9.16294460e+00,  -2.27836789e+00,
#         -6.19548838e+00,   1.31483110e+01,   1.28581622e+01,
#          8.64767004e+00,  -1.03998560e+01,  -1.83832158e+01,
# ...

# %%
np.random.multivariate_normal(np.zeros(400), 100 * np.identity(400), 800).shape
# Out:
# (800, 400)
